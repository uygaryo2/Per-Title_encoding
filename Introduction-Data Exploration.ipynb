# %%
#import packages
import pandas as pd

# %%
#Previously I have chang
clip=pd.read_csv('/Users/sezin/PycharmProjects/AWT/data/clip.csv')
clip.head()
# Out:
#    Unnamed: 0  id                                           filename  \
# 0           0   5  /Volumes/pte/content/upload/watchfolder/touchd...
# 1           1   6  /Volumes/pte/content/upload/watchfolder/aspen_...
# 2           2   7  /Volumes/pte/content/upload/watchfolder/freeri...
# 3           3   8  /Volumes/pte/content/upload/watchfolder/contro...
# 4           4   9  /Volumes/pte/content/upload/watchfolder/aspen_...
#
#   format_long_name  duration       size  bitrate_total video_codec  \
# 0  QuickTime / MOV        19   41249088       17350686        h264
# 1  QuickTime / MOV        19  378608416      159254815        h264
# 2  QuickTime / MOV       182  281454443       12370128        h264
# 3  QuickTime / MOV        19  280986702      118191998        h264
# 4  QuickTime / MOV        19  231039918       97182782        h264
#
#            video_profile  width  height sample_aspect_ratio  \
# 0             High 4:2:2   1920    1080                 1:1
# ...

# %%
encode=pd.read_csv('/Users/sezin/PycharmProjects/AWT/data/encode.csv')
encode.head()
# Out:
#    Unnamed: 0  id  width  height video_codec  crf       psnr       vmaf  \
# 0           0   7   1920    1080     libx264   18  44.621550  99.406406
# 1           1   8   1920    1080     libx264   19  44.051502  99.192502
# 2           2   9   1920    1080     libx264   20  43.408926  98.924590
# 3           3  10   1920    1080     libx264   27  38.802828  89.462670
# 4           4  11   1920    1080     libx264   29  37.790129  84.728349
#
#    gop_size  b_frame_interval  reference_frames  frame_rate  \
# 0       NaN               NaN               NaN         NaN
# 1       NaN               NaN               NaN         NaN
# 2       NaN               NaN               NaN         NaN
# 3       NaN               NaN               NaN         NaN
# 4       NaN               NaN               NaN         NaN
#
#                                             filename      state  \
# 0  /Volumes/pte/content/encoding/5-1920-1080-18-7...  completed
# ...

# %%
label=pd.read_csv('/Users/sezin/PycharmProjects/AWT/data/label.csv')
label.head()
# Out:
#    Unnamed: 0  id  probability  time  image_number  \
# 0           0   1    90.181071   NaN             1
# 1           1   2    66.776872   NaN             2
# 2           2   3    94.055784   NaN             4
# 3           3   4    90.004504   NaN             5
# 4           4   5    95.129001   NaN             6
#
#                                                value  \
# 0  punching bag, punch bag, punching ball, punchball
# 1  punching bag, punch bag, punching ball, punchball
# 2  punching bag, punch bag, punching ball, punchball
# 3  punching bag, punch bag, punching ball, punchball
# 4  punching bag, punch bag, punching ball, punchball
#
#                    classifier           created_at           updated_at  \
# 0  image_classifier_mobilenet  2019-04-08 07:23:42  2019-04-08 07:23:42
# 1  image_classifier_mobilenet  2019-04-08 07:23:42  2019-04-08 07:23:42
# 2  image_classifier_mobilenet  2019-04-08 07:23:42  2019-04-08 07:23:42
# ...

# %%
scene_change=pd.read_csv('/Users/sezin/PycharmProjects/AWT/data/scene_change.csv')
scene_change.head()
# Out:
#    Unnamed: 0  id  percentage  pts  pts_time  pos           created_at  \
# 0           0   1         0.2  NaN      2.34  NaN  2019-04-08 09:09:32
# 1           1   2         0.2  NaN      4.68  NaN  2019-04-08 09:09:32
# 2           2   3         0.2  NaN      7.14  NaN  2019-04-08 09:09:32
# 3           3   4         0.2  NaN      9.74  NaN  2019-04-08 09:09:32
# 4           4   5         0.2  NaN     11.42  NaN  2019-04-08 09:09:32
#
#             updated_at  clip_id
# 0  2019-04-08 09:09:32      7.0
# 1  2019-04-08 09:09:32      7.0
# 2  2019-04-08 09:09:32      7.0
# 3  2019-04-08 09:09:32      7.0
# 4  2019-04-08 09:09:32      7.0
